# %%
from manim import * 
config.media_embed = True
from manim_mobject_svg import *
# Out:
# Manim Community v0.17.1

# %%
ManimBanner(dark_theme=False).scale(0.2)
# Out:
# ManimBanner(VGroup of 3 submobjects, MathTex('\\mathbb{M}'))

# %%
ParametricFunction(lambda t: [t, 0.2 * np.sin(10 * t), 0], t_range=[-TAU, TAU], color=YELLOW)
# Out:
# ParametricFunction

# %%
line1 = Line((LEFT + (1 / 3) * UP) * 0.1, RIGHT + (1 / 3) * DOWN, color=RED)  
line2 = Line((DOWN + (1 / 3) * RIGHT) * 0.1, UP + (1 / 3) * LEFT, color=BLUE) 
angle = Angle(line1, line2, radius=0.3,color=GREEN)  
value = Integer(angle.get_value(degrees=True), unit="^{\circ}", color=YELLOW)  
value.next_to(angle, UR, buff=0) 
VGroup(line1, line2, angle, value).move_to(ORIGIN)
# Out:
# VGroup(Line, Line, Angle, Integer)

# %%
func = lambda pos: np.sin(pos[1]) * RIGHT + np.cos(pos[0]) * UP  
mob = ArrowVectorField(func).scale(0.4)
mob
# Out:
# ArrowVectorField(Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vector, Vecto
# ...
